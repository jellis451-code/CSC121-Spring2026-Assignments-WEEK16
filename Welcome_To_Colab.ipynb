# %% [markdown]
# <a href="https://colab.research.google.com/github/jellis451-code/CSC121-Spring2026-Assignments-WEEK16/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Expense Tracker
# PART 1: STRUCTURE & PSEUDOCODE

# Create empty list to store expenses

# Start main loop
    # Show menu:
        # 1 Add Expense
        # 2 Get Totals
        # 3 Exit

    # If user chooses 1:
        # Ask for category, vendor, amount, date
        # Store expense as a dictionary:
            # {"category": "", "vendor": "", "amount": 0.0, "date": ""}
        # Add dictionary to list

    # If user chooses 2:
        # Show options:
            # A = total all
            # C = total by category
            # V = total by vendor

        # If A:
            # Loop through list and add all amounts

        # If C:
            # Ask for category
            # Loop and only add matching category

        # If V:
            # Ask for vendor
            # Loop and only add matching vendor

    # If user chooses 3:
        # Exit program
